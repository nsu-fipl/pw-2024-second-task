# %% [markdown]
# # Дело о двенадцати знаках

# %% [markdown]
# ```Недавно мне вспомнился один случай: на дворе стоял летний, по-настоящему солнечный день, один из тех дней, в которые просто сидеть так хорошо, что не всегда находишь желание даже просто поднять руку с трубкой.```
#
# ```Мы с Шерлоком сидели в гостинной, мы оба просматривали газеты в надежде найти новое, стоящее дело. Холмс искал нетерпеливо, быстро```
# ```переключаясь с одной газеты на другую. Казалось, в его действиях нет никакого порядка и логики, но я, уже приученный ждать от него```
#  ```что угодно, знал, что это часть какой-то очередной методики, которая настолько сложна, что для меня неотличима от магии.```
#
# ```- Взгляните только, Ватсон! - возмущенно воскликнул он. - В этих газетах опять печатают гороскопы, я надеялся, что эта мода```
#  ```уже прошла. Пустая трата места, ненужная информация! - продолжал Шерлок.```
# ```- Не знал, что вы так скептично к ним расположены. Знаете, многие знакомые мне дамы считают, что они не лишены смысла. И даже я``` ``` уже почти начал им доверять.```
# ```- Думаю, вы слишком много времени проводите с этими знакомыми дамами. - отрезал он. - Несомненно, это развивает вашу``` ```наблюдательность, но, чувствую, вряд ли хорошо влияет на ваш интеллект. Все эти гороскопы, карты таро и все подобное - антинаучная```
#  ```чушь, которая никак не соответствует моему аналитическому подходу как к жизни, так и к работе.```
# ```- А если вы все же неправы? - его самодовольный и наставительный тон задел меня. - Что, если зная знак зодиака, можно определить,```
#  ```например, склонность человека к преступлениям? Или то, насколько он подвержен состоянию аффекта?```
# ```- Ватсон, не будьте так наивны! Все это полная ерунда и я вам это докажу!```

# %% [markdown]
# ![New Project(63).jpg](attachment:036f091b-7625-4dcc-8feb-e422d1ecc027.jpg)

# %% [markdown]
# Итак, в этом задании вам нужно будет помочь Шерлоку доказать неправоту Ватсона (опять).
# Хотя, кто знает, может быть мы докажем обратное...
#
# Вы получите данные психологического теста, который содержит в себе следующую информацию:
# - знак зодиака
# - факультет
# - средний уровень агрессии
#
# Ваша задача - построить графики, которые покажут, есть ли зависимость между знаком зодиака и уровнем агрессии. Для построения графиков мы воспользуемся библиотекой *Matplotlib*

# %% [markdown]
# ## MatPlotLib
#
# Библиотека matplotlib - это бибилиотека двумерной графики для языка программирования Python с помощью которой можно создавать графики различных форматов. Matplotlib представляет собой модуль-пакет для Python.

# %% [markdown]
# ## Line charts
#
# Для начала узнаем как строить обычные графики. Вот как построить параболу:

# %%
from matplotlib import pyplot as plt # из модуля matplotlib импортируем подмодуль pyplot и называем его plt

xs = [x / 10.0 for x in range(-30, 30)] # задаем точки, по которым будем строить график
ys = [x**2 for x in xs] # задаем квадраты этих чисел

plt.plot(xs, ys) # запоминаем, какой график строить

plt.show() # показываем график

# %% [markdown]
# Теперь давайте построим график для зависимости уровня агрессии от знака зодиака. Сначала объявим массивы с данными о знаках зодиака:

# %%
zodiac_signs = ["Козерог", "Водолей", "Рыбы", "Овен", "Телец", "Близнецы", "Рак", "Лев", "Дева", "Весы", "Скорпион", "Стрелец"]
zodiac_agr = [2.76, 4.39, 3.79, 4.2, 3.57, 4.47, 4.42, 4.86, 4.76, 4.5, 4.08, 3.33]

# %% [markdown]
# Теперь в следующей ячейке вам нужно написать код для построения графика по этим данным (по аналогии с тем, как построили параболу). Также нужно:
# - подписать график (`plt.title("Some title)"`). Подписать нужно график как `"Зависимость уровня агрессии от знака зодиака"`
# - подписать оси (`plt.xlabel("X label")`, `plt.ylabel("Y label")`. Для оси x - `"Уровень агрессии"`, для y - `"Знак зодиака"`

# %%
# восстановление настроек по умолчанию, не удалять!
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

# Ваш код

# %% [markdown]
# По графику сейчас сложно понять, к какому знаку зодиака относится какой уровень. Давайте добавим сетку с помощью `plt.grid()` и точки на графике.
#
# В коде ниже нужно:
# - добавить сетку на график
# - добавить точки-маркеры на график (маркеры должны быть кружками)
# - сделать линию пунктирной
#
# Чтобы добавить точки и сделать линию пунктирной есть два варианта:
# - передать третьим аргументом в `plt.plot()` [формат строку](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html), раздел `Format strings`
# - передать в вызов функции `plt.plot()` два именованных параметра: `marker` и `linestyle`
#
# Вам нужно сделать задание воспользовавшись вторым вариантом.
# Как именно задать тип маркеров и стиль линии написано по ссылке в документации выше

# %%
# восстановление настроек по умолчанию, не удалять!
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

# Ваш код, можно скопировать из предыдущей ячейки и подредактировать

# %% [markdown]
# Теперь давайте добавим на график еще две линии:
#
# - уровень агрессии по знакам зодиака для студентов ФИТа
# - уровень агрессии по знакам зодиака для студентов ГИ
#
# Данные для них указаны ниже. Вам нужно:
#
# - покрасить линии в новые цвета. для ФИТа сделать линию оранжевой, ГИ - синей, общую статистику - черной. Линии для факультетов должны быть сплошные, общая линия все так же прерывистой
# - подписать линии (подписи `"ФИТ"`, `"ГИ"`)
#
#
# Подсказки:
# - Чтобы покрасить линию в цвет в вызов `plt.plot()` достаточно добавить еще один именованный аргумент `color`. Что в него передать можно посмотреть в документации
# - Чтобы нарисовать на графике сразу несколько линий нужно несколько раз вызвать функцию `plt.plot()` (для каждой из линий)
# - Чтобы подписать линии добавьте в `plt.plot()` именованный аргумент `label`. Его значение - строка с подписью для линии. Перед `plt.show()` добавьте вызов `plt.legend()` - эта команда нарисует ваши подписи на графике
# - Цвета можно задавать не только буквами как в формат строках, но и hex кодами. Например, для оранжевого можно написать `#FFA500`

# %%
zodiac_fit_agr = [2.0, 3.0, 6.67, 3.44, 0.0, 3.0, 0.0, 4.0, 5.0, 3.33, 0.0, 0.0]
zodiac_gi_agr = [0.0, 5.11, 3.33, 0.0, 4.67, 5.44, 5.06, 7.0, 4.83, 5.67, 5.83, 0.0]

# %%
# восстановление настроек по умолчанию, не удалять!
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

# Ваш код, можно скопировать из предыдущей ячейки и подредактировать

# %% [markdown]
# На графике также можно подписывать какие-то точки, делается это с помощью функции `plt.annotate`.
#
# Например вызов:
# ```
# plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
#             arrowprops=dict(facecolor='black', shrink=0.05),
#             )
# ```
#
# Подписывает сообщение `local max` к точке x = 2, y = 1, с отступом немного вверх (начинает на 3 и 1.5) и рисует черную стрелку.
#
# Добавьте вызов `plt.annotate`. На графике подпишите точку с вашим показателем агрессии (бралось среднеарифметическое по трем ответам, если не помните, то подпишите просто какую-нибудь точку для своего знака). Подпись - `Агрессия, моя агрессия`

# %%
# восстановление настроек по умолчанию, не удалять!
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

# Ваш код, можно скопировать из предыдущей ячейки и подредактировать

# %% [markdown]
# Последнее, что нужно сделать - изменить стиль графика. Для этого сначала давайте посмотрим доступные нам стили:

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# Постройте график с любым понравившимся вам стилем. Для этого допишите первой строкой в вашем коде `plt.style.use('название стиля')`
#
# `plt.annotate` нужно убрать, в дальнейшем она нам не понадобится

# %%
# восстановление настроек по умолчанию, не удалять!
import matplotlib as mpl

mpl.rcParams.update(mpl.rcParamsDefault)

# Ваш код, можно скопировать из предыдущей ячейки и подредактировать

# %% [markdown]
# ## Bar charts
#
# Как вы могли заметить, на линейном графике наша статистика плохо видна, давайте воспользуемся столбчатыми диаграммами.
#
# Пример столбчатой диаграммы (на ней отображен средний уровень агрессии по результатам опроса):

# %%
# восстановление настроек по умолчанию, не удалять!
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

from matplotlib import pyplot as plt

plt.bar(['Male', 'Female'], [3.75, 4.42])
plt.show()

# %% [markdown]
# Для начала попробуем взять код из прошлого раздела и немного подредактировать вызовы метода `plt.plot()`:
#
# - Предварительно уберем из вызовов `plt.plot()` ненужные параметры - тип линии и тип маркера
# - Сам вызов заменим на вызов `plt.bar()`. По оси х расположим знаки зодиака, по оси y - уровень агрессии

# %%
# восстановление настроек по умолчанию, не удалять!
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

# Ваш код, можно скопировать из предыдущей ячейки и подредактировать

# %% [markdown]
# Как видите, появилось две проблемы на графике:
# - знаки зодиака сливаются. с этим легко побороться, достаточно использовать `plt.barh()` вместо `plt.bar()`. тогда по `y` у нас будут знаки зодиака, а по `x` - уровень агрессии
# - стоблцы наезжают друг на друга. мы бы хотели их расположить рядом с небольшим отступом
#
# Для исправления второй проблемы нужно:
# - указать явно размер столбцов в вызове `plt.barh()`. это можно сделать, передав именованный параметр `height` с числовым значением (мы сделаем 0.25)
# - при отрисовке сдвинуть столбцы чуть выше и ниже, ровно на высоту стобца (для этого вместо знаков зодиака будем использовать их индексы)

# %%
import numpy as np # математическая библиотека, более подробно рассмотрим ее в одной из будущих лаб

height = 0.25

zodiac_idx = np.arange(len(zodiac_signs)) # получили вектор индексов от 0 до 11
zodiac_fit_idx = zodiac_idx + height # прибавить к каждому компоненту вектора индексов константу, чтобы рисовать чуть выше, т.е будут 0.25, 1.25 и т.д.
zodiac_gi_idx = zodiac_idx - height # аналогично вычесть

# %% [markdown]
# Теперь перерисуйте столбчатые диаграммы, используя индексы:
#
# - вместо `plt.bar()` используйте `plt.barh()`
# - передайте height в качестве именованного аргумента в `plt.barh()`
# - теперь вместо `zodiac_signs` подставьте подходящий набор индексов из тех, которые объявили выше

# %%
# восстановление настроек по умолчанию, не удалять!
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

# Ваш код, можно скопировать из предыдущей ячейки и подредактировать

# %% [markdown]
# Так лучше, но теперь вместо знака зодиака мы видем его индекс. Чтобы это поправить можно воспользоваться функцией `plt.yticks()`
#
# Эта функция принимает два параметра:
# - первый - на каких позициях мы хотим добавить подписи (нужно указать там `zodiac_idx`)
# - второй - что подписывать (передадим туда `zodiac_signs`)
#
# После этого должны получится красивые графики по знакам зодиака. Для некоторых знаков (например, для стрельца) вы увидите только один столбец или только два - это нормально, это значит, что на никто с этих факультетов этого знака зодиака не заполнил анкету.

# %%
# восстановление настроек по умолчанию, не удалять!
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

# Ваш код, можно скопировать из предыдущей ячейки и подредактировать

# %% [markdown]
# ## Histograms
#
# В завершении научимся строить гистограммы с помощью `matplotlib`. В качестве примера посмотрим распределение уровня агрессии.
#
# Для начала объявим массив со всеми значениями агрессии из выборки:

# %%
agression = [ 4.3, 3.7, 3.0, 4.3, 5.7, 7.0, 2.3, 7.0, 3.3, 3.7, 3.3, 6.7, 4.7, 1.7, 3.3, 1.7, 2.7, 4.7, 3.3, 6.7, 2.7, 3.3, 2.7, 10.0, 4.0, 3.7, 5.3, 2.0, 3.0, 6.0, 7.3, 7.3, 2.3, 3.7, 6.7, 2.0, 4.0, 1.7, 1.0, 4.0, 6.3, 3.7, 3.0, 6.0, 5.0, 2.0, 2.7, 5.7, 1.0, 2.3, 4.7, 2.0, 5.7, 3.7, 6.7, 6.0, 4.0, 2.7, 5.7, 7.3, 4.7, 2.0, 3.3, 1.7, 7.0, 6.3, 3.0, 5.0, 1.0, 3.3]

# %% [markdown]
# Теперь построим гистограмму. Для этого нужно вызвать метод `plt.hist()`. Первым параметром он принимает выборку, которую будем рисовать, вторым `bins` - число интервалов, в которые попадут наши значения. Например, если мы укажем 4 бина, то все значения агрессии разобьются на 4 равные части и для них нарисуются столбцы. Давайте попробуем это сделать.

# %%
# восстановление настроек по умолчанию, не удалять!
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

# Ваш код

# %% [markdown]
# Сейчас разбиение происходит автоматически, давайте укажем явно, для каких интервалов мы хотим построить столбцы. Для этого в качестве bins можно передать массив границ наших интервалов. Т.е. если, например, передать `bins=[1, 5, 10]`, то у нас появятся два столбца, один для значений от 1 до 5, второй для значений от 5 до 10.
#
# Разбейте агрессию на 4 равных интервала (посчитайте сами, какие у них должны быть границы). Также давайте добавим границы столбцов, сейчас они сливаются друг с другом. Сделать это можно передав `edgecolor=black` в `plt.hist()`

# %%
# восстановление настроек по умолчанию, не удалять!
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

# Ваш код, можно скопировать из предыдущей ячейки и подредактировать

# %% [markdown]
# ## Как сдавать лабу
#
# В репозитории с заданием лежит файл `test_zodiac.py`. Нужно его отредактировать, вставив туда код, который вы написали **последним** в каждом разделе.
# Всего было три раздела:
#
# - `Line charts` - вставить код, где вы изменяли стиль графика
# - `Bar charts` - вставить код, где вы применили `plt.barh` и сдвинули столбцы на `width`
# - `Histograms` - предыдущая ячейка с кодом
#
# Внимание! Нужно удалить `plt.show()` из вашего кода в конце. Также нужно убрать стили графика, если они установлены
# Внимание! Не забудьте скопировать еще и объявление массивов со значениями, которые рисуем (знаки зодиака, уровни агрессии...).
#
# После того, как отредактируете, код нужно отправить на гитхаб
